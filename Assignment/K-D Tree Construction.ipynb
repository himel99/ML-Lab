# %%
from collections import namedtuple
from operator import itemgetter
from pprint import pformat

class Node(namedtuple("Node", "location left_child right_child")):
    def __repr__(self):
        return pformat(tuple(self))

def kdtree(point_list, depth: int = 0):
    if not point_list:
        return None

    k = len(point_list[0])  # assumes all points have the same dimension
    # Select axis based on depth so that axis cycles through all valid values
    axis = depth % k

    # Sort point list by axis and choose median as pivot element
    point_list.sort(key=itemgetter(axis))
    median = len(point_list) // 2

    # Create node and construct subtrees
    return Node(
        location=point_list[median],
        left_child=kdtree(point_list[:median], depth + 1),
        right_child=kdtree(point_list[median + 1 :], depth + 1),
    )

def main(test_arr):
    """Example usage"""
    #point_list = [(7, 2), (5, 4), (9, 6), (4, 7), (8, 1), (2, 3)]
    point_list = test_arr
    tree = kdtree(point_list)
    print(tree)
    return tree

# %%
import pandas as pd
import numpy as np

# %%
data_set = pd.read_csv('diabetes.csv')
data_set
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
modified_data = data_set
modified_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
#test_data = modified_data.drop('Pregnancies',axis=1)
test_data = modified_data.drop('SkinThickness',axis=1)
test_data = test_data.drop('BloodPressure',axis=1)
test_data = test_data.drop('BMI',axis=1)
test_data = test_data.drop('Age',axis=1)
test_data = test_data.drop('DiabetesPedigreeFunction',axis=1)
test_data = test_data.drop('Insulin',axis=1)
test_data
# Out:
#      Pregnancies  Glucose  Outcome
# 0              6      148        1
# 1              1       85        0
# 2              8      183        1
# 3              1       89        0
# 4              0      137        1
# ..           ...      ...      ...
# 763           10      101        0
# 764            2      122        0
# 765            5      121        0
# 766            1      126        1
# 767            1       93        0
#
# [768 rows x 3 columns]

# %%
test = test_data.drop('Outcome',axis=1)
test_arr = test.to_numpy()
test_arr
# Out:
# array([[  6, 148],
#        [  1,  85],
#        [  8, 183],
#        ...,
#        [  5, 121],
#        [  1, 126],
#        [  1,  93]], dtype=int64)

# %%
point_list = [(7, 2), (5, 4), (9, 6), (4, 7), (8, 1), (2, 3)]
point_list[0][1]
test_list = test_arr.tolist()
test_list[0]
# Out:
# [6, 148]

# %%
t = main(test_list)
# Out:
# ([3, 100],
#  ([1, 112],
#  ([1, 100],
#  ([1, 93],
#  ([1, 80],
#  ([0, 78],
#  ([1, 0],
#  ([0, 67],
#  ([1, 0], ([0, 57], None, None), ([1, 0], None, None)),
#  ([0, 74], ([0, 73], None, None), None)),
#  ([1, 71],
#  ([1, 71], ([1, 71], None, None), None),
#  ([1, 77], ([1, 73], None, None), None))),
#  ([0, 93],
#  ([0, 86],
#  ([0, 84], ([0, 84], None, None), None),
#  ([0, 91], ([0, 91], None, None), None)),
#  ([1, 79],
#  ([1, 79], ([1, 79], None, None), None),
#  ([0, 93], ([0, 93], None, None), None)))),
#  ([1, 88],
#  ([1, 84],
#  ([1, 81],
#  ([1, 81], ([1, 80], None, None), None),
#  ([1, 83], ([1, 82], None, None), None)),
#  ([1, 87],
#  ([1, 86], ([1, 85], None, None), None),
#  ([1, 87], ([1, 87], None, None), None))),
#  ([1, 90],
#  ([1, 89],
#  ([1, 88], ([1, 88], None, None), None),
#  ([1, 89], ([1, 89], None, None), None)),
#  ([1, 91],
#  ([1, 90], ([1, 90], None, None), None),
#  ([1, 92], ([1, 91], None, None), None))))),
#  ([0, 105],
#  ([0, 101],
#  ([0, 97],
#  ([0, 95],
#  ([0, 94], ([0, 94], None, None), None),
#  ([0, 95], ([0, 95], None, None), None)),
#  ([0, 100],
#  ([0, 99], ([0, 98], None, None), None),
#  ([0, 101], ([0, 100], None, None), None))),
#  ([0, 102],
#  ([0, 102],
#  ([0, 101], ([0, 101], None, None), None),
#  ([0, 102], ([0, 102], None, None), None)),
#  ([0, 104],
#  ([0, 104], ([0, 102], None, None), None),
#  ([0, 105], ([0, 104], None, None), None)))),
#  ([1, 97],
#  ([1, 96],
#  ([1, 95],
#  ([1, 95], ([1, 93], None, None), None),
#  ([1, 95], ([1, 95], None, None), None)),
#  ([1, 97],
#  ([1, 97], ([1, 96], None, None), None),
#  ([1, 97], ([1, 97], None, None), None))),
#  ([0, 107],
#  ([0, 106],
#  ([0, 105], ([0, 105], None, None), None),
#  ([0, 107], ([0, 107], None, None), None)),
#  ([0, 108],
#  ([1, 99], ([1, 99], None, None), None),
#  ([0, 111], ([0, 109], None, None), None)))))),
#  ([1, 100],
#  ([2, 90],
#  ([2, 84],
#  ([2, 75],
#  ([2, 68],
#  ([2, 68], ([2, 56], None, None), None),
#  ([2, 74], ([2, 71], None, None), None)),
#  ([2, 82],
#  ([2, 81], ([2, 81], None, None), None),
#  ([2, 83], ([2, 83], None, None), None))),
#  ([2, 88],
#  ([2, 87],
#  ([2, 85], ([2, 84], None, None), None),
#  ([2, 87], ([1, 100], None, None), None)),
#  ([2, 90],
#  ([2, 89], ([2, 88], None, None), None),
#  ([2, 90], ([2, 90], None, None), None)))),
#  ([2, 93],
#  ([3, 74],
#  ([2, 92],
#  ([3, 61], ([2, 91], None, None), None),
#  ([2, 92], ([2, 92], None, None), None)),
#  ([3, 83],
#  ([3, 81], ([3, 78], None, None), None),
#  ([3, 90], ([3, 88], None, None), None))),
#  ([2, 99],
#  ([2, 95],
#  ([2, 94], ([2, 94], None, None), None),
#  ([2, 98], ([2, 96], None, None), None)),
#  ([2, 99],
#  ([2, 99], ([2, 99], None, None), None),
#  ([3, 99], ([3, 99], None, None), None))))),
#  ([2, 100],
#  ([1, 107],
#  ([1, 105],
#  ([1, 102],
#  ([1, 101], ([1, 100], None, None), None),
#  ([1, 103], ([1, 103], None, None), None)),
#  ([1, 106],
#  ([2, 100], ([2, 100], None, None), None),
#  ([1, 107], ([1, 106], None, None), None))),
#  ([1, 109],
#  ([1, 108],
#  ([1, 108], ([1, 107], None, None), None),
#  ([1, 109], ([1, 109], None, None), None)),
#  ([1, 111],
#  ([1, 111], ([1, 109], None, None), None),
#  ([1, 112], ([1, 111], None, None), None)))),
#  ([3, 107],
#  ([2, 105],
#  ([2, 101],
#  ([2, 100], ([2, 100], None, None), None),
#  ([2, 102], ([2, 101], None, None), None)),
#  ([2, 106],
#  ([2, 105], ([2, 105], None, None), None),
#  ([2, 107], ([2, 106], None, None), None))),
#  ([2, 109],
#  ([2, 108],
#  ([2, 108], ([2, 108], None, None), None),
#  ([2, 108], ([2, 108], None, None), None)),
#  ([3, 111],
#  ([2, 111], ([2, 110], None, None), None),
#  ([3, 111], ([3, 111], None, None), None))))))),
#  ([1, 135],
#  ([1, 128],
#  ([1, 113],
#  ([0, 120],
#  ([0, 117],
#  ([0, 114],
#  ([0, 113], ([0, 113], None, None), None),
#  ([0, 117], ([0, 117], None, None), None)),
#  ([0, 119],
#  ([0, 118], ([0, 118], None, None), None),
#  ([0, 119], ([0, 119], None, None), None))),
#  ([0, 125],
#  ([0, 123],
#  ([0, 123], ([0, 121], None, None), None),
#  ([0, 124], ([0, 124], None, None), None)),
#  ([0, 126],
#  ([0, 126], ([0, 125], None, None), None),
#  ([0, 128], ([0, 127], None, None), None)))),
#  ([1, 120],
#  ([1, 117],
#  ([1, 116],
#  ([1, 115], ([1, 114], None, None), None),
#  ([1, 117], ([1, 116], None, None), None)),
#  ([1, 119],
#  ([1, 119], ([1, 118], None, None), None),
#  ([1, 119], ([1, 119], None, None), None))),
#  ([1, 125],
#  ([1, 122],
#  ([1, 122], ([1, 121], None, None), None),
#  ([1, 124], ([1, 124], None, None), None)),
#  ([1, 126],
#  ([1, 126], ([1, 125], None, None), None),
#  ([1, 128], ([1, 128], None, None), None))))),
#  ([0, 151],
#  ([0, 137],
#  ([0, 132],
#  ([0, 131],
#  ([0, 129], ([0, 129], None, None), None),
#  ([0, 131], ([0, 131], None, None), None)),
#  ([0, 135],
#  ([0, 135], ([0, 134], None, None), None),
#  ([0, 137], ([0, 137], None, None), None))),
#  ([0, 141],
#  ([0, 138],
#  ([0, 138], ([0, 137], None, None), None),
#  ([0, 140], ([0, 139], None, None), None)),
#  ([0, 146],
#  ([0, 145], ([0, 141], None, None), None),
#  ([0, 147], ([0, 146], None, None), None)))),
#  ([0, 167],
#  ([0, 165],
#  ([0, 162],
#  ([0, 161], ([0, 152], None, None), None),
#  ([0, 165], ([0, 162], None, None), None)),
#  ([1, 130],
#  ([1, 130], ([1, 128], None, None), None),
#  ([1, 133], ([1, 131], None, None), None))),
#  ([0, 180],
#  ([0, 179],
#  ([0, 177], ([0, 173], None, None), None),
#  ([0, 180], ([0, 179], None, None), None)),
#  ([0, 188],
#  ([0, 181], ([0, 180], None, None), None),
#  ([0, 198], ([0, 189], None, None), None)))))),
#  ([2, 142],
#  ([2, 124],
#  ([2, 120],
#  ([2, 114],
#  ([2, 112],
#  ([2, 112], ([2, 112], None, None), None),
#  ([2, 112], ([2, 112], None, None), None)),
#  ([2, 118],
#  ([2, 117], ([2, 115], None, None), None),
#  ([2, 120], ([2, 119], None, None), None))),
#  ([2, 121],
#  ([1, 139],
#  ([1, 138], ([1, 136], None, None), None),
#  ([1, 140], ([1, 139], None, None), None)),
#  ([2, 122],
#  ([2, 122], ([2, 122], None, None), None),
#  ([2, 123], ([2, 122], None, None), None)))),
#  ([2, 128],
#  ([3, 113],
#  ([2, 125],
#  ([3, 113], ([3, 112], None, None), None),
#  ([2, 127], ([2, 127], None, None), None)),
#  ([3, 120],
#  ([3, 116], ([3, 115], None, None), None),
#  ([3, 126], ([3, 122], None, None), None))),
#  ([2, 134],
#  ([2, 129],
#  ([2, 129], ([2, 128], None, None), None),
#  ([2, 130], ([2, 129], None, None), None)),
#  ([3, 139],
#  ([3, 128], ([2, 139], None, None), None),
#  ([3, 141], ([2, 141], None, None), None))))),
#  ([1, 199],
#  ([1, 163],
#  ([1, 146],
#  ([1, 143],
#  ([1, 143], ([1, 143], None, None), None),
#  ([1, 144], ([1, 144], None, None), None)),
#  ([1, 151],
#  ([1, 149], ([1, 147], None, None), None),
#  ([1, 157], ([1, 153], None, None), None))),
#  ([1, 180],
#  ([1, 168],
#  ([1, 167], ([1, 164], None, None), None),
#  ([1, 173], ([1, 172], None, None), None)),
#  ([1, 189],
#  ([1, 181], ([1, 181], None, None), None),
#  ([1, 196], ([1, 193], None, None), None)))),
#  ([3, 158],
#  ([2, 155],
#  ([2, 146],
#  ([2, 146], ([2, 144], None, None), None),
#  ([2, 155], ([2, 146], None, None), None)),
#  ([3, 150],
#  ([3, 148], ([3, 142], None, None), None),
#  ([2, 158], ([2, 157], None, None), None))),
#  ([3, 170],
#  ([2, 175],
#  ([3, 162], ([2, 174], None, None), None),
#  ([2, 197], ([2, 197], None, None), None)),
#  ([3, 180],
#  ([3, 173], ([3, 171], None, None), None),
#  ([3, 191], ([3, 182], None, None), None)))))))),
#  ([4, 123],
#  ([6, 93],
#  ([4, 99],
#  ([4, 96],
#  ([3, 89],
#  ([3, 84],
#  ([3, 80],
#  ([3, 80], ([3, 78], None, None), None),
#  ([3, 84], ([3, 82], None, None), None)),
#  ([4, 84],
#  ([4, 83], ([4, 76], None, None), None),
#  ([4, 85], ([3, 87], None, None), None))),
#  ([4, 91],
#  ([3, 96],
#  ([4, 90], ([4, 90], None, None), None),
#  ([3, 99], ([3, 96], None, None), None)),
#  ([4, 95],
#  ([4, 94], ([4, 92], None, None), None),
#  ([4, 95], ([4, 95], None, None), None)))),
#  ([6, 87],
#  ([5, 85],
#  ([5, 73],
#  ([5, 44], ([5, 0], None, None), None),
#  ([5, 78], ([5, 77], None, None), None)),
#  ([6, 80],
#  ([6, 80], ([6, 0], None, None), None),
#  ([6, 85], ([5, 86], None, None), None))),
#  ([5, 95],
#  ([4, 97],
#  ([5, 88], ([5, 88], None, None), None),
#  ([4, 99], ([4, 99], None, None), None)),
#  ([6, 92],
#  ([6, 92], ([6, 91], None, None), None),
#  ([5, 97], ([5, 96], None, None), None))))),
#  ([4, 118],
#  ([3, 111],
#  ([3, 108],
#  ([3, 103],
#  ([3, 102], ([3, 102], None, None), None),
#  ([3, 106], ([3, 106], None, None), None)),
#  ([4, 110],
#  ([4, 109], ([4, 103], None, None), None),
#  ([4, 110], ([4, 110], None, None), None))),
#  ([4, 114],
#  ([3, 116],
#  ([4, 112], ([4, 111], None, None), None),
#  ([3, 123], ([3, 121], None, None), None)),
#  ([4, 116],
#  ([4, 115], ([4, 114], None, None), None),
#  ([4, 117], ([4, 117], None, None), None)))),
#  ([5, 112],
#  ([5, 106],
#  ([5, 103],
#  ([5, 99], ([5, 99], None, None), None),
#  ([5, 105], ([5, 104], None, None), None)),
#  ([5, 109],
#  ([5, 109], ([5, 108], None, None), None),
#  ([5, 111], ([5, 110], None, None), None))),
#  ([5, 116],
#  ([5, 115],
#  ([5, 115], ([5, 114], None, None), None),
#  ([4, 122], ([4, 120], None, None), None)),
#  ([5, 117],
#  ([5, 117], ([5, 116], None, None), None),
#  ([5, 122], ([5, 121], None, None), None)))))),
#  ([6, 105],
#  ([8, 99],
#  ([7, 97],
#  ([8, 65],
#  ([7, 83],
#  ([7, 81], ([7, 62], None, None), None),
#  ([7, 94], ([6, 96], None, None), None)),
#  ([8, 85],
#  ([8, 84], ([8, 74], None, None), None),
#  ([8, 95], ([8, 91], None, None), None))),
#  ([6, 103],
#  ([6, 102],
#  ([6, 99], ([6, 98], None, None), None),
#  ([6, 103], ([6, 102], None, None), None)),
#  ([7, 103],
#  ([7, 102], ([7, 100], None, None), None),
#  ([6, 105], ([6, 104], None, None), None)))),
#  ([10, 92],
#  ([10, 75],
#  ([9, 72],
#  ([10, 68], ([9, 57], None, None), None),
#  ([9, 91], ([9, 89], None, None), None)),
#  ([11, 85],
#  ([13, 76], ([12, 84], None, None), None),
#  ([12, 88], ([10, 90], None, None), None))),
#  ([10, 101],
#  ([8, 100],
#  ([10, 94], ([8, 100], None, None), None),
#  ([10, 101], ([9, 102], None, None), None)),
#  ([14, 100],
#  ([12, 100], ([12, 92], None, None), None),
#  ([13, 104], ([11, 103], None, None), None))))),
#  ([8, 112],
#  ([8, 109],
#  ([7, 106],
#  ([6, 107],
#  ([7, 106], ([7, 105], None, None), None),
#  ([6, 109], ([6, 108], None, None), None)),
#  ([8, 107],
#  ([8, 105], ([7, 107], None, None), None),
#  ([8, 108], ([7, 109], None, None), None))),
#  ([6, 119],
#  ([6, 114],
#  ([6, 114], ([6, 111], None, None), None),
#  ([6, 117], ([6, 115], None, None), None)),
#  ([7, 114],
#  ([8, 110], ([7, 114], None, None), None),
#  ([7, 119], ([7, 114], None, None), None)))),
#  ([10, 115],
#  ([10, 115],
#  ([10, 111],
#  ([10, 108], ([9, 106], None, None), None),
#  ([9, 112], ([9, 112], None, None), None)),
#  ([13, 106],
#  ([13, 106], ([12, 106], None, None), None),
#  ([11, 111], ([10, 115], None, None), None))),
#  ([9, 120],
#  ([8, 120],
#  ([9, 119], ([8, 118], None, None), None),
#  ([8, 120], ([8, 120], None, None), None)),
#  ([9, 122],
#  ([12, 121], ([11, 120], None, None), None),
#  ([10, 122], ([10, 122], None, None), None))))))),
#  ([6, 190],
#  ([6, 144],
#  ([4, 144],
#  ([4, 129],
#  ([4, 123],
#  ([3, 128],
#  ([3, 125], ([3, 124], None, None), None),
#  ([3, 129], ([3, 129], None, None), None)),
#  ([4, 127],
#  ([4, 125], ([4, 125], None, None), None),
#  ([4, 129], ([4, 128], None, None), None))),
#  ([4, 132],
#  ([4, 131],
#  ([3, 130], ([3, 130], None, None), None),
#  ([4, 132], ([3, 132], None, None), None)),
#  ([4, 137],
#  ([4, 136], ([4, 134], None, None), None),
#  ([4, 142], ([4, 141], None, None), None)))),
#  ([5, 132],
#  ([6, 123],
#  ([5, 126],
#  ([5, 124], ([5, 123], None, None), None),
#  ([5, 130], ([5, 128], None, None), None)),
#  ([6, 125],
#  ([6, 125], ([6, 124], None, None), None),
#  ([6, 129], ([6, 125], None, None), None))),
#  ([5, 139],
#  ([5, 137],
#  ([5, 136], ([5, 136], None, None), None),
#  ([5, 139], ([4, 144], None, None), None)),
#  ([6, 137],
#  ([6, 134], ([6, 134], None, None), None),
#  ([5, 144], ([5, 143], None, None), None))))),
#  ([4, 183],
#  ([3, 158],
#  ([4, 147],
#  ([4, 146],
#  ([4, 146], ([4, 145], None, None), None),
#  ([4, 146], ([3, 158], None, None), None)),
#  ([4, 154],
#  ([4, 151], ([4, 148], None, None), None),
#  ([4, 156], ([4, 154], None, None), None))),
#  ([3, 176],
#  ([3, 173],
#  ([3, 169], ([3, 163], None, None), None),
#  ([3, 174], ([3, 173], None, None), None)),
#  ([4, 173],
#  ([4, 171], ([4, 158], None, None), None),
#  ([3, 193], ([3, 187], None, None), None)))),
#  ([6, 162],
#  ([5, 162],
#  ([5, 155],
#  ([5, 147], ([5, 147], None, None), None),
#  ([5, 158], ([5, 158], None, None), None)),
#  ([6, 151],
#  ([6, 148], ([6, 147], None, None), None),
#  ([6, 154], ([6, 154], None, None), None))),
#  ([5, 168],
#  ([4, 184],
#  ([5, 166], ([5, 166], None, None), None),
#  ([4, 197], ([4, 189], None, None), None)),
#  ([6, 183],
#  ([6, 166], ([6, 165], None, None), None),
#  ([5, 189], ([5, 187], None, None), None)))))),
#  ([9, 152],
#  ([9, 130],
#  ([8, 133],
#  ([8, 124],
#  ([7, 129],
#  ([7, 125], ([7, 124], None, None), None),
#  ([7, 133], ([7, 133], None, None), None)),
#  ([8, 125],
#  ([9, 124], ([9, 123], None, None), None),
#  ([8, 126], ([8, 126], None, None), None))),
#  ([7, 147],
#  ([7, 137],
#  ([7, 136], ([7, 136], None, None), None),
#  ([7, 142], ([7, 142], None, None), None)),
#  ([7, 150],
#  ([8, 143], ([7, 150], None, None), None),
#  ([8, 151], ([7, 152], None, None), None)))),
#  ([11, 138],
#  ([11, 127],
#  ([10, 129],
#  ([10, 129], ([10, 125], None, None), None),
#  ([10, 133], ([9, 134], None, None), None)),
#  ([11, 135],
#  ([13, 129], ([13, 126], None, None), None),
#  ([15, 136], ([11, 136], None, None), None))),
#  ([11, 138],
#  ([9, 145],
#  ([10, 139], ([9, 140], None, None), None),
#  ([10, 148], ([9, 145], None, None), None)),
#  ([11, 143],
#  ([12, 140], ([12, 140], None, None), None),
#  ([13, 145], ([12, 151], None, None), None))))),
#  ([8, 186],
#  ([8, 179],
#  ([7, 178],
#  ([7, 160],
#  ([7, 159], ([7, 159], None, None), None),
#  ([7, 168], ([7, 161], None, None), None)),
#  ([8, 167],
#  ([8, 155], ([8, 154], None, None), None),
#  ([8, 176], ([7, 179], None, None), None))),
#  ([7, 187],
#  ([7, 187],
#  ([7, 184], ([7, 181], None, None), None),
#  ([6, 195], ([6, 194], None, None), None)),
#  ([7, 194],
#  ([8, 183], ([8, 181], None, None), None),
#  ([7, 196], ([7, 195], None, None), None)))),
#  ([9, 164],
#  ([10, 162],
#  ([9, 156],
#  ([9, 156], ([9, 154], None, None), None),
#  ([10, 161], ([9, 164], None, None), None)),
#  ([11, 155],
#  ([13, 153], ([13, 152], None, None), None),
#  ([17, 163], ([13, 158], None, None), None))),
#  ([9, 170],
#  ([8, 194],
#  ([9, 165], ([8, 188], None, None), None),
#  ([8, 197], ([8, 196], None, None), None)),
#  ([14, 175],
#  ([10, 168], ([9, 171], None, None), None),
#  ([10, 179], ([9, 184], None, None), None)))))))))

# %%
test_list[0][1]
# Out:
# 137

# %%
from collections import namedtuple
from operator import itemgetter
from pprint import pformat

class Node(namedtuple("Node", "location left_child right_child")):
    def __repr__(self):
        return pformat(tuple(self))

def kdtree(point_list, depth: int = 0):
    if not point_list:
        return None

    k = len(point_list[0])  # assumes all points have the same dimension
    # Select axis based on depth so that axis cycles through all valid values
    axis = depth % k

    # Sort point list by axis and choose median as pivot element
    point_list.sort(key=itemgetter(axis))
    median = len(point_list) // 2
    
    if (point_list[median][0] < 1 ): 
            left_child=kdtree(point_list[:median], depth + 1)
            print(left_child)
      
    mytuple = tuple(map(int, Node.left_child.split(' ')))
    print(mytuple)

    # Create node and construct subtrees
    return Node(
        location=point_list[median],
            left_child= kdtree(point_list[:median], depth + 1) if (point_list[median][0] > 1 ) else 'None', 
            right_child=kdtree( point_list[median + 1 :], depth + 1)if (point_list[median][1] < 140 ) else 'None',
    )

def main(test_arr):
    """Example usage"""
    #point_list = [(7, 2), (5, 4), (9, 6), (4, 7), (8, 1), (2, 3)]
    point_list = test_arr
    tree = kdtree(point_list)
    print(tree)
    return tree

# %%
a = main(test_list)
a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-1d254ff1e150> in <module>
# ----> 1 a = main(test_list)
#       2 a
#
# <ipython-input-70-06d2e5d6520b> in main(test_arr)
#      37     #point_list = [(7, 2), (5, 4), (9, 6), (4, 7), (8, 1), (2, 3)]
#      38     point_list = test_arr
# ---> 39     tree = kdtree(point_list)
#      40     print(tree)
#      41     return tree
#
# <ipython-input-70-06d2e5d6520b> in kdtree(point_list, depth)
#      23             print(left_child)
#      24
# ---> 25     mytuple = tuple(map(int, Node.left_child.split(' ')))
#      26     print(mytuple)
#      27
#
# AttributeError: '_collections._tuplegetter' object has no attribute 'split'

# %%
a = np.array(a)
a
# Out:
# array([list([3, 100]), ([1, 112], 'None', 'None'), 'None'], dtype=object)

# %%
# initializing list
test_list = a
  
# printing original list 
print ("The original list is : " + str(test_list))
  
# using naive method 
# to remove None values in list
res = []
for val in test_list:
    if val != 'None' :
        res.append(val)
  
# printing result
print ("List after removal of None values : " +  str(res))
# Out:
# The original list is : [list([3, 100]) ([1, 112], 'None', 'None') 'None']
# List after removal of None values : [[3, 100], ([1, 112], 'None', 'None')]
